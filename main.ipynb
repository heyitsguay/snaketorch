# %%
from agent import train
from game import SnakeGame
# Out:
# pygame 2.1.2 (SDL 2.0.16, Python 3.10.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # Manual game

# %%
game = SnakeGame(w=960, h=720)

# %% [markdown]
# # AI training game

# %%
train(960, 720)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 train(960, 720)
#
# File /media/DataDrive/Dropbox/code/snaketorch/agent.py:138, in train(w, h)
#     135 final_move = agent.get_action(state_old)
#     137 # perform move and get new state
# --> 138 reward, done, score = game.play_step(final_move)
#     139 state_new = agent.get_state(game)
#     141 # train short memory
#
# File /media/DataDrive/Dropbox/code/snaketorch/ai_game.py:96, in AISnakeGame.play_step(self, action)
#      94 elif event.key == pygame.K_q:
#      95     pygame.quit()
# ---> 96     quit()
#      97 elif event.key == pygame.K_i:
#      98     self.agent.lr = min(0.1, self.agent.trainer.get_lr() * 1.05)
#
# NameError: name 'quit' is not defined
